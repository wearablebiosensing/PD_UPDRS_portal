# %%
import pandas as pd 
import numpy as np 
import numpy as np                   # for multi-dimensional containers
import pandas as pd                  # for DataFrames
import plotly.graph_objects as go    # for data visualisation
from plotly.subplots import make_subplots
import scipy.fftpack                 # discrete Fourier transforms
import matplotlib.pyplot as plt

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
import numpy as np
import json
import glob
from sklearn import preprocessing
import gspread as gs
from scipy.signal import find_peaks
import plotly.figure_factory as ff
import calendar
from scipy.signal import chirp, find_peaks, peak_widths
import scipy.fftpack                 # discrete Fourier transforms
from scipy.signal import find_peaks, peak_prominences
from scipy.signal import butter, lfilter

# %%
from scipy import signal

# %%
# Takes in a numpy array and calculates fft using scipi .
# Returns: frequency component - f and P1: - the apmplitude. 
def my_fft(fft_data):
    Fs = 64 # Sampling Rate 
    T = 1/Fs
    L =len(fft_data) # Length of the dataset.
    #print("my_fft(): ",L)
    t = np.arange(start=0, stop=L-1, step=1) *T # Timestamp bins.
    f = np.arange(start=0, stop=L-1, step=1)/L * Fs # 
    #print("my_fft(): ",fft_data, type(fft_data))
    sig_fft_out = scipy.fftpack.fft(fft_data)
    # The corresponding frequencies
   # print("sig_fft_out: ",len(sig_fft_out))

    P2 = abs(sig_fft_out/L)
   # print("my_fft(fft_data): P2 - abs(sig_fft_out/L) ", P2,len(P2))
   # print("my_fft(fft_data): int(L/2+1): ",int(L/2+1))
    P1 = P2[1:int(L)]
    #print("my_fft(): P1: ",len(P1),P1)
    P1[2:len(P1)-1] = 2*P1[2:len(P1)-1]
    return f,P1,sig_fft_out

# %%
# Returns a list of filepaths and date IDs at which the exercises were performed.
def read_iotex_data(participant_id,reaults_file_name):
    np.set_printoptions(suppress=True)
    root = "/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/"
    df_rg_paths = pd.read_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/" + reaults_file_name) # reaults_file - results_p2.csv
    print(df_rg_paths["Participant"])
    df_rg_paths = df_rg_paths[df_rg_paths["Participant"]==participant_id]
    
    df_rg_paths["RandomPeaks"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["Method1_TimeBased"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["Method3_FreqBased"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["width_threshold"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["Method3_DominantFreqLowerBound"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["Method3_DominantFreqUpperBound"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    df_rg_paths["SNR_mean_std"] = np.linspace(-911, -911, num=df_rg_paths.shape[0], endpoint=False)
    peak2peak_diff_freq_list = []
    for index, row in df_rg_paths.iterrows():
        print("===========================",row["Participant"] +"/"+ row["DateList"] + "/" + row["FileName"],"===========================")
#         if row["FileName"].startswith("rg_"):
        df = pd.read_csv(root+row["Participant"] +"/"+ row["DateList"] + "/" + row["FileName"])
        print("Index of row index: ",index)
        # Subset the Finger tapping activity.
        if row["FileName"].startswith("rg_"):
            df_finger_tapping = df[df["activity"]==1]
        if row["FileName"].startswith("lg_"):
             df_finger_tapping = df[df["activity"]==0]
        # Subset 2.5 seconds of data.
        start_idx = 100
        end_idx = start_idx+160 
        #print("df_finger_tappin unique(): ",df_finger_tapping["activity"].unique())
        #print("df_finger_tapping.shape: ",df_finger_tapping.shape)
        if df_finger_tapping.shape[0]>=160:
             #################### ------------------------ PREPROCESSING ------------------------ ####################
            df_finger_tapping_2_5 = df_finger_tapping[start_idx:end_idx]
            print(df_finger_tapping_2_5.activity.unique(),df_finger_tapping_2_5.shape) # should be only activity 1 and 160 samples.
            #print(df_finger_tapping_2_5["index"])
            # Normalize the  raw index finger values.
            # df_finger_tapping_2_5_index_norm is a <class 'numpy.ndarray'> of shape (1, 160) 
            #take df_finger_tapping_2_5_index_norm[0] to get the actual array of values of lingth 160.
            df_finger_tapping_2_5_index_norm = signal.detrend(preprocessing.normalize([df_finger_tapping_2_5["index"]])) #df_lg_activity[column_id]#
            print("df_finger_tapping_2_5_index_norm:",type(df_finger_tapping_2_5_index_norm[0]))
            #################### ------------------------ TIME BASED ------------------------ ####################
            #print("len(df_finger_tapping_2_5_index_norm): ",len(df_finger_tapping_2_5_index_norm), len(df_finger_tapping_2_5_index_norm[0]))
            # Run Random peak detector. 
            indices,properties_peaks = find_peaks(df_finger_tapping_2_5_index_norm[0], height=np.quantile(df_finger_tapping_2_5_index_norm[0], 0.50))
            print("Number of Peaks: ", len(indices))
            df_rg_paths.at[index,'RandomPeaks']   =len(indices)
            # find the widths of the peak detected by the random peak detector.
            peak_width = peak_widths(df_finger_tapping_2_5_index_norm[0], indices, rel_height=0.5)
            width_threshold = peak_width[0].mean()
            indicies_p2, properties_peaks_p2 =find_peaks(df_finger_tapping_2_5_index_norm[0], height=np.quantile(df_finger_tapping_2_5_index_norm[0], 0.50),width =width_threshold)
            peaks_timebased =[df_finger_tapping_2_5_index_norm[0][j] for j in indicies_p2]
            df_rg_paths.at[index,'width_threshold'] =width_threshold 
            df_rg_paths.at[index,'Method1_TimeBased'] =len(indicies_p2)

            #################### ------------------------ FREQUENCY BASED ------------------------ ####################
#             print("df_finger_tapping_2_5_index_norm: ",df_finger_tapping_2_5_index_norm[0])
            frequency,amplitude,sample_freq = my_fft(df_finger_tapping_2_5_index_norm[0])
            high_freq_fft = frequency.copy()
            bounds = 2
            
           # print("amplitude max: ",np.array(amplitude).argmax(),type(amplitude),len(amplitude),"Feq Len",len(sample_freq))
            #print("Dominant frequency (freq where the amplitude is the heightse): ",frequency[np.array(amplitude).argmax()].real)

            high_freq_fft[:np.array(amplitude).argmax()-bounds] = 0
            high_freq_fft[np.array(amplitude).argmax()+bounds:] = 0
            filtered_sig = scipy.fftpack.ifft(high_freq_fft)
            filt_f,filt_P1,filt_sample_freq= my_fft(filtered_sig.real)
            filt_indices,filt_properties_peaks = find_peaks(filtered_sig.real, height=np.quantile(filtered_sig.real, 0.50))
            filt_peaks =[filtered_sig.real[j] for j in filt_indices]
            print("filt_peaks: ",len(filt_peaks))
            print("index: ",index)
            peak2peak_diff_freq = [filt_peaks[i + 1] - filt_peaks[i] for i in range(len(filt_peaks)-1)]
            peak2peak_diff_time = [peaks_timebased[i + 1] - peaks_timebased[i] for i in range(len(peaks_timebased)-1)]
            print("Difference filt peaks peak2peak_diff_freq:",peak2peak_diff_freq)
            print("Difference filt peaks peak2peak_diff_time:",peak2peak_diff_time)
            peak2peak_diff_freq_list.append(peak2peak_diff_freq)

            df_rg_paths.at[index,'Method3_FreqBased'] = len(filt_peaks)
            df_rg_paths.at[index,'Method3_DominantFreq'] = frequency[np.array(amplitude).argmax()].real
            np.set_printoptions(suppress=True)
            df_rg_paths.at[index,'SNR_mean_std'] = np.mean(df_finger_tapping_2_5_index_norm[0])/np.std(df_finger_tapping_2_5_index_norm[0])
            #df_rg_paths.at[index,'Method3_DominantFreqLowerBound'] = frequency[np.array(amplitude).argmax()-bounds].real
            #df_rg_paths.at[index,'Method3_DominantFreqUpperBound'] = frequency[np.array(amplitude).argmax()+bounds].real
    return df_rg_paths, peak2peak_diff_freq_list

# %%
root_results_write = "/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/"

# %%
results_p1,peak2peak_diff_freq_list = read_iotex_data("Participant1","results_p1.csv")
# Out:
# 0     Participant1
# 1     Participant1
# 2     Participant1
# 3     Participant1
# 4     Participant1
# 5     Participant1
# 6     Participant1
# 7     Participant1
# 8     Participant1
# 9     Participant1
# 10    Participant1
# 11    Participant1
# 12    Participant1
# 13    Participant1
# 14    Participant1
# 15    Participant1
# 16    Participant1
# 17    Participant1
# 18    Participant1
# 19    Participant1
# 20    Participant1
# 21    Participant1
# 22    Participant1
# 23    Participant1
# 24    Participant1
# 25    Participant1
# 26    Participant1
# 27    Participant1
# 28    Participant1
# 29    Participant1
# 30    Participant1
# 31    Participant1
# 32    Participant1
# 33    Participant1
# 34    Participant1
# 35    Participant1
# 36    Participant1
# 37    Participant1
# 38    Participant1
# 39    Participant1
# 40    Participant1
# 41    Participant1
# Name: Participant, dtype: object
# =========================== Participant1/2021-06-25/rg_20210625-172211.csv ===========================
# Index of row index:  0
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  9
# filt_peaks:  8
# index:  0
# Difference filt peaks peak2peak_diff_freq: [-0.04040127694467967, 0.010801854821466408, -0.008020138908638364, 0.0, 0.008020138908638364, -0.010801854821466408, 0.04040127694467967]
# Difference filt peaks peak2peak_diff_time: [-0.0012773673912220007, 0.0005363151818160439, -0.0001437530111530888, 0.0010951183874170906]
# =========================== Participant1/2021-06-25/rg_20210625-071807.csv ===========================
# Index of row index:  1
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  7
# filt_peaks:  7
# index:  1
# Difference filt peaks peak2peak_diff_freq: [-0.029613340347115196, 0.010330098391331904, -0.012531304260518208, 0.012531304260518208, -0.010330098391331904, 0.029613340347115196]
# Difference filt peaks peak2peak_diff_time: [0.0004041756774195715, -0.0014065468673286619]
# =========================== Participant1/2021-06-24/rg_20210624-170825.csv ===========================
# Index of row index:  2
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  8
# filt_peaks:  7
# index:  2
# Difference filt peaks peak2peak_diff_freq: [-0.029613340347115196, 0.010330098391331904, -0.012531304260518208, 0.012531304260518208, -0.010330098391331904, 0.029613340347115196]
# Difference filt peaks peak2peak_diff_time: [0.0006996209482421356, 0.0008854112373790357, -0.0017987838351252866, -0.0003012611970729523]
# =========================== Participant1/2021-07-06/rg_20210706-070145.csv ===========================
# Index of row index:  3
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  9
# filt_peaks:  8
# index:  3
# Difference filt peaks peak2peak_diff_freq: [-0.04040127694467967, 0.010801854821466408, -0.008020138908638364, 0.0, 0.008020138908638364, -0.010801854821466408, 0.04040127694467967]
# Difference filt peaks peak2peak_diff_time: [-0.0022186359885633944, 0.0012091315050288542, -7.49629190957557e-07, 0.0031244955232636457, -0.002119988567668832]
# =========================== Participant1/2021-07-01/rg_20210701-212116.csv ===========================
# Index of row index:  4
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  9
# filt_peaks:  9
# index:  4
# Difference filt peaks peak2peak_diff_freq: [-0.04637189676902903, 0.0019020041075672317, 0.004125772276817787, -0.01563711683723694, 0.01563711683723694, -0.004125772276817787, -0.0019020041075672317, 0.04637189676902903]
# Difference filt peaks peak2peak_diff_time:
# 27         11.0                5.0                9.0         5.128083
# 28         15.0               10.0                9.0         5.668072
# 29          7.0                6.0                6.0         9.921583
# 30         11.0                7.0                7.0         5.674404
# 31         14.0                7.0               10.0         5.203154
# 32         15.0                6.0                5.0         6.282777
# 33         12.0                8.0                9.0         5.676591
# 34         10.0                6.0                9.0         6.231515
# 35         13.0                8.0               11.0         5.212749
# 36         16.0               10.0                6.0         5.797856
# 37         19.0                8.0                7.0         2.981128
# 38         19.0                6.0                3.0         4.502825
# 39         20.0                9.0                7.0         4.224551
# 40         15.0                7.0               11.0         5.161465
# 41         22.0               10.0               11.0         3.887397
#
#     Method3_DominantFreqLowerBound  Method3_DominantFreqUpperBound  \
# 0                           -911.0                          -911.0
# 1                           -911.0                          -911.0
# 2                           -911.0                          -911.0
# 3                           -911.0                          -911.0
# 4                           -911.0                          -911.0
# 5                           -911.0                          -911.0
# 6                           -911.0                          -911.0
# 7                           -911.0                          -911.0
# 8                           -911.0                          -911.0
# 9                           -911.0                          -911.0
# 10                          -911.0                          -911.0
# 11                          -911.0                          -911.0
# 12                          -911.0                          -911.0
# 13                          -911.0                          -911.0
# 14                          -911.0                          -911.0
# 15                          -911.0                          -911.0
# 16                          -911.0                          -911.0
# 17                          -911.0                          -911.0
# 18                          -911.0                          -911.0
# 19                          -911.0                          -911.0
# 20                          -911.0                          -911.0
# 21                          -911.0                          -911.0
# 22                          -911.0                          -911.0
# 23                          -911.0                          -911.0
# 24                          -911.0                          -911.0
# 25                          -911.0                          -911.0
# 26                          -911.0                          -911.0
# 27                          -911.0                          -911.0
# 28                          -911.0                          -911.0
# 29                          -911.0                          -911.0
# 30                          -911.0                          -911.0
# 31                          -911.0                          -911.0
# 32                          -911.0                          -911.0
# 33                          -911.0                          -911.0
# 34                          -911.0                          -911.0
# 35                          -911.0                          -911.0
# 36                          -911.0                          -911.0
# 37                          -911.0                          -911.0
# 38                          -911.0                          -911.0
# 39                          -911.0                          -911.0
# 40                          -911.0                          -911.0
# 41                          -911.0                          -911.0
#
#     SNR_mean_std  Method3_DominantFreq
# 0   3.919042e-15                   3.2
# 1   2.726991e-15                   2.8
# 2   1.747370e-15                   2.8
# 3   1.664150e-15                   3.2
# 4   5.590565e-15                   3.6
# 5   2.194118e-15                   3.2
# 6   3.025636e-15                   2.8
# 7   3.747262e-15                   2.4
# 8   7.472726e-15                   2.8
# 9  -3.578935e-16                   2.8
# 10  7.135631e-15                   3.2
# 11  9.512503e-15                   3.6
# 12  1.776004e-15                   3.2
# 13  5.229091e-15                   3.2
# 14  9.318159e-16                   3.6
# 15  3.188666e-15                   3.2
# 16 -9.110000e+02                   NaN
# 17  6.418309e-15                   3.2
# 18  6.282367e-15                   3.2
# 19  1.818288e-15                   3.2
# 20  7.067642e-15                   3.2
# 21  4.473112e-14                   2.8
# 22  2.096964e-15                   2.4
# 23  7.329697e-15                   2.8
# 24  3.518748e-14                   3.2
# 25  2.461602e-14                   3.6
# 26  1.198242e-13                   3.2
# 27  6.679281e-15                   3.6
# 28  3.014473e-15                   3.6
# 29  4.864418e-15                   2.4
# 30  3.027082e-14                   2.8
# 31  3.442497e-15                   4.0
# 32  5.200976e-15                   2.0
# 33  5.253544e-14                   3.6
# 34  1.627308e-14                   3.6
# 35  1.367265e-14                   4.4
# 36  6.293732e-14                   2.4
# 37  1.596355e-13                   2.8
# 38  4.801433e-15                  62.8
# 39  1.445557e-14                   2.8
# 40  1.349394e-13                   4.4
# 41  3.588370e-15                   4.4

# %%
results_p2 = read_iotex_data("Participant2","results_p2.csv")
# Out:
# 0     Participant2
# 1     Participant2
# 2     Participant2
# 3     Participant2
# 4     Participant2
# 5     Participant2
# 6     Participant2
# 7     Participant2
# 8     Participant2
# 9     Participant2
# 10    Participant2
# 11    Participant2
# 12    Participant2
# 13    Participant2
# 14    Participant2
# 15    Participant2
# 16    Participant2
# 17    Participant2
# 18    Participant2
# 19    Participant2
# 20    Participant2
# 21    Participant2
# 22    Participant2
# 23    Participant2
# 24    Participant2
# 25    Participant2
# 26    Participant2
# 27    Participant2
# 28    Participant2
# 29    Participant2
# Name: Participant, dtype: object
# =========================== Participant2/2021-07-06/rg_20210706-105513.csv ===========================
# Index of row index:  0
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  25
# filt_peaks:  7
# index:  0
# Difference filt peaks peak2peak_diff_freq: [-0.029613340347115196, 0.010330098391331904, -0.012531304260518208, 0.012531304260518208, -0.010330098391331904, 0.029613340347115196]
# Difference filt peaks peak2peak_diff_time: [0.0002028466746720331, 0.00021166274616762903, -0.0002402764633917115, 6.836306922751445e-05, -0.00030090621249227734, 0.00022488685341104375]
# =========================== Participant2/2021-07-06/rg_20210706-095943.csv ===========================
# Index of row index:  1
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  26
# filt_peaks:  6
# index:  1
# Difference filt peaks peak2peak_diff_freq: [-0.015402503457888848, 0.0004240553059390497, 0.0, -0.0004240553059390497, 0.015402503457888848]
# Difference filt peaks peak2peak_diff_time: [-0.00012828393635881674, 0.00034963831738679674, -6.300979511492111e-05, -0.00019618348573249844, 1.5391386777918736e-05]
# =========================== Participant2/2021-07-01/rg_20210701-001106.csv ===========================
# Index of row index:  2
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  22
# filt_peaks:  7
# index:  2
# Difference filt peaks peak2peak_diff_freq: [-0.029613340347115196, 0.010330098391331904, -0.012531304260518208, 0.012531304260518208, -0.010330098391331904, 0.029613340347115196]
# Difference filt peaks peak2peak_diff_time: [0.00015173861506280473, 5.188289200860896e-06, -0.00036255385651021155, 9.259272992236112e-05, -0.00013883715081661196, -5.119030444936112e-06]
# =========================== Participant2/2021-07-01/rg_20210701-092555.csv ===========================
# Index of row index:  3
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  18
# filt_peaks:  6
# index:  3
# Difference filt peaks peak2peak_diff_freq: [-0.015402503457888848, 0.0004240553059390497, 0.0, -0.0004240553059390497, 0.015402503457888848]
# Difference filt peaks peak2peak_diff_time: [0.0002470710931279374, -0.00016767603389246377, 6.4754982090659e-05, -0.00011756112894660553, 4.248169100362631e-05]
# =========================== Participant2/2021-07-08/rg_20210708-213728.csv ===========================
# Index of row index:  4
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  28
# filt_peaks:  3
# index:  4
# Difference filt peaks peak2peak_diff_freq: [-0.061132236352155374, 0.061132236352155374]
# Difference filt peaks peak2peak_diff_time: [-0.00027310129748395195, 0.00014906980797947667, -0.00013530707945941245, -1.0446543766598482e-05, 2.338022609826851e-05, 0.00016117444412276638, -4.4273313631437716e-05, -0.00021589430152080258, 0.00010877619694876772]
# =========================== Participant2/2021-06-30/rg_20210630-153050.csv ===========================
# Index of row index:  5
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  9
# filt_peaks:  7
# index:  5
# Difference filt peaks peak2peak_diff_freq: [-0.029613340347115196, 0.010330098391331904, -0.012531304260518208, 0.012531304260518208, -0.010330098391331904, 0.029613340347115196]
# Difference filt peaks peak2peak_diff_time: [0.0008383597386811409]
# =========================== Participant2/2021-06-28/rg_20210628-153436.csv ===========================
# Index of row index:  6
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  21
# filt_peaks:  6
# index:  6
# Difference filt peaks peak2peak_diff_freq: [-0.015402503457888848, 0.0004240553059390497, 0.0, -0.0004240553059390497, 0.015402503457888848]
# Difference filt peaks peak2peak_diff_time: [6.300328500988273e-05, -0.00015633713739550414, -0.00015633713739549027, -0.0001354779908926962]
# =========================== Participant2/2021-06-28/rg_20210628-151121.csv ===========================
# Index of row index:  7
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:
# 1                     6         26.0                6.0                6.0
# 2                     9         22.0                7.0                7.0
# 3                     6         18.0                6.0                6.0
# 4                     8         28.0               10.0                3.0
# 5                     3          9.0                2.0                7.0
# 6                     5         21.0                5.0                6.0
# 7                     6         17.0                6.0                7.0
# 8                     8         27.0                8.0                7.0
# 9                     7         29.0                5.0                7.0
# 10                    7         32.0               11.0                6.0
# 11                   10         33.0                9.0                7.0
# 12  14 (HARD TO DETECT)         31.0               10.0                3.0
# 13                    6         10.0                6.0                6.0
# 14                   13         27.0               10.0                6.0
# 15       HARD TO DETECT         35.0                7.0                3.0
# 16                    8         29.0                9.0                7.0
# 17            NO SIGNAL         20.0                6.0                3.0
# 18                    7         22.0                6.0                7.0
# 19                  NaN         25.0                7.0                7.0
# 20                    8         18.0                2.0                0.0
# 21                    8         17.0                7.0                7.0
# 22            NO SIGNAL          3.0                1.0                3.0
# 23                    8         23.0                8.0                7.0
# 24                    8         23.0                7.0                7.0
# 25                    7         26.0                8.0                6.0
# 26                    8         31.0                7.0                7.0
# 27                    8         30.0               10.0                7.0
# 28                    8         24.0                8.0                7.0
# 29                    7          9.0                3.0                6.0
#
#     width_threshold  Method3_DominantFreqLowerBound  \
# 0          3.623354                          -911.0
# 1          3.172708                          -911.0
# 2          3.718897                          -911.0
# 3          5.134499                          -911.0
# 4          2.873223                          -911.0
# 5          7.607807                          -911.0
# 6          3.457472                          -911.0
# 7          3.807424                          -911.0
# 8          3.096529                          -911.0
# 9          3.394024                          -911.0
# 10         2.308766                          -911.0
# 11         3.931129                          -911.0
# 12         2.863763                          -911.0
# 13         7.018478                          -911.0
# 14         3.061145                          -911.0
# 15         2.464113                          -911.0
# 16         3.151237                          -911.0
# 17         3.609883                          -911.0
# 18         3.140163                          -911.0
# 19         3.840485                          -911.0
# 20         9.010310                          -911.0
# 21         7.492484                          -911.0
# 22        12.605766                          -911.0
# 23         3.702813                          -911.0
# 24         3.890110                          -911.0
# 25         4.041617                          -911.0
# 26         2.476592                          -911.0
# 27         2.987859                          -911.0
# 28         4.725916                          -911.0
# 29        16.256605                          -911.0
#
#     Method3_DominantFreqUpperBound  SNR_mean_std  Method3_DominantFreq
# 0                           -911.0  1.797937e-14                   2.8
# 1                           -911.0  1.366978e-14                   2.4
# 2                           -911.0  3.330043e-14                   2.8
# 3                           -911.0  2.997637e-14                   2.4
# 4                           -911.0  6.390693e-14                  62.8
# 5                           -911.0  3.917674e-14                   2.8
# 6                           -911.0  3.153468e-14                   2.4
# 7                           -911.0  3.894673e-14                   2.8
# 8                           -911.0  4.404831e-14                   2.8
# 9                           -911.0  5.221511e-14                   2.8
# 10                          -911.0  2.207868e-13                   2.4
# 11                          -911.0  6.206581e-14                   2.8
# 12                          -911.0  1.277458e-13                  62.8
# 13                          -911.0  1.977040e-14                   2.4
# 14                          -911.0  5.731683e-14                   2.4
# 15                          -911.0  1.032322e-13                  62.8
# 16                          -911.0  1.046687e-13                   2.8
# 17                          -911.0  1.580073e-13                  62.8
# 18                          -911.0  3.125027e-14                   2.8
# 19                          -911.0  2.175993e-13                   2.8
# 20                          -911.0  8.539557e-14                   0.0
# 21                          -911.0  1.458738e-13                   2.8
# 22                          -911.0  4.380428e-15                  62.8
# 23                          -911.0  6.585572e-14                   2.8
# 24                          -911.0  6.886133e-14                   2.8
# 25                          -911.0  3.927841e-14                   2.4
# 26                          -911.0  3.570877e-14                   2.8
# 27                          -911.0  3.701363e-13                   2.8
# 28                          -911.0  5.447487e-14                   2.8
# 29                          -911.0  7.213367e-15                   2.4

# %%
results_p3 = read_iotex_data("Participant3","results_p3.csv")
# Out:
# 0     Participant3
# 1     Participant3
# 2     Participant3
# 3     Participant3
# 4     Participant3
# 5     Participant3
# 6     Participant3
# 7     Participant3
# 8     Participant3
# 9     Participant3
# 10    Participant3
# 11    Participant3
# 12    Participant3
# 13    Participant3
# 14    Participant3
# 15    Participant3
# 16    Participant3
# 17    Participant3
# 18    Participant3
# 19    Participant3
# 20    Participant3
# 21    Participant3
# 22    Participant3
# 23    Participant3
# 24    Participant3
# 25    Participant3
# 26    Participant3
# 27    Participant3
# 28    Participant3
# 29    Participant3
# 30    Participant3
# 31    Participant3
# 32    Participant3
# 33    Participant3
# 34    Participant3
# 35    Participant3
# 36    Participant3
# 37    Participant3
# 38    Participant3
# 39    Participant3
# Name: Participant, dtype: object
# =========================== Participant3/2021-07-12/rg_20210712-105043.csv ===========================
# Index of row index:  0
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  19
# filt_peaks:  3
# index:  0
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-2.082352845082791e-05, -0.00015372220035429762]
# =========================== Participant3/2021-07-12/rg_20210712-084406.csv ===========================
# Index of row index:  1
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  10
# filt_peaks:  3
# index:  1
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-0.0007664551759000021, -0.0010075056576884095]
# =========================== Participant3/2021-07-15/rg_20210715-085044.csv ===========================
# Index of row index:  2
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  15
# filt_peaks:  3
# index:  2
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-0.00018847531835905484, -0.0001530587190774063]
# =========================== Participant3/2021-07-15/rg_20210715-074541.csv ===========================
# Index of row index:  3
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  14
# filt_peaks:  3
# index:  3
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [9.611150583516137e-05, 0.00041527657631985904]
# =========================== Participant3/2021-07-14/rg_20210714-074534.csv ===========================
# Index of row index:  4
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  23
# filt_peaks:  3
# index:  4
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-0.00045054302634253696, 0.00014011326618394715, 7.928342444159242e-05]
# =========================== Participant3/2021-07-14/rg_20210714-104520.csv ===========================
# Index of row index:  5
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  9
# filt_peaks:  3
# index:  5
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-0.0007567313822984534, 0.00036052838606508153, 0.0002904137716004812]
# =========================== Participant3/2021-07-13/rg_20210713-104541.csv ===========================
# Index of row index:  6
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  4
# filt_peaks:  2
# index:  6
# Difference filt peaks peak2peak_diff_freq: [0.0]
# Difference filt peaks peak2peak_diff_time: [0.00024206063581337645, 3.4992750649470716e-06]
# =========================== Participant3/2021-07-13/rg_20210713-075054.csv ===========================
# Index of row index:  7
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  6
# filt_peaks:  3
# index:  7
# Difference filt peaks peak2peak_diff_freq: [-0.0014019996815512878, 0.0014019996815512878]
# Difference filt peaks peak2peak_diff_time: [-0.0010101254887613237, 0.0007148213001910847, 0.00020824844563219203]
# =========================== Participant3/2021-07-09/rg_20210709-103945.csv ===========================
# Index of row index:  8
# [1] (160, 20)
# df_finger_tapping_2_5_index_norm: <class 'numpy.ndarray'>
# Number of Peaks:  25
# filt_peaks:  8
# index:  8
# Difference filt peaks peak2peak_diff_freq: [-0.04040127694467967, 0.010801854821466408, -0.008020138908638364, 0.0, 0.008020138908638364, -0.010801854821466408, 0.04040127694467967]
# Difference filt peaks peak2peak_diff_time:
# 10         6.068217                          -911.0
# 11         5.228272                          -911.0
# 12         5.479796                          -911.0
# 13         2.143691                          -911.0
# 14         3.955301                          -911.0
# 15        21.406269                          -911.0
# 16        12.828929                          -911.0
# 17         4.258789                          -911.0
# 18         5.745148                          -911.0
# 19        13.795638                          -911.0
# 20         4.399737                          -911.0
# 21         5.647906                          -911.0
# 22         7.176292                          -911.0
# 23        12.558594                          -911.0
# 24         7.730468                          -911.0
# 25         9.587388                          -911.0
# 26         6.243518                          -911.0
# 27         7.556196                          -911.0
# 28         3.087335                          -911.0
# 29         2.828803                          -911.0
# 30         6.869255                          -911.0
# 31         1.686047                          -911.0
# 32         6.902371                          -911.0
# 33         3.208244                          -911.0
# 34         4.908303                          -911.0
# 35         7.037407                          -911.0
# 36         6.625051                          -911.0
# 37         5.426954                          -911.0
# 38         5.889334                          -911.0
# 39         8.136494                          -911.0
#
#     Method3_DominantFreqUpperBound  SNR_mean_std  Method3_DominantFreq
# 0                           -911.0  5.444197e-14                   1.2
# 1                           -911.0  4.216466e-15                   1.2
# 2                           -911.0  1.154578e-14                   1.2
# 3                           -911.0  1.139723e-14                   1.2
# 4                           -911.0  5.885772e-14                   1.2
# 5                           -911.0  1.396399e-14                   1.2
# 6                           -911.0  8.645867e-15                   0.8
# 7                           -911.0  3.976580e-15                   1.2
# 8                           -911.0  5.101097e-13                   3.2
# 9                           -911.0  2.899018e-15                   1.2
# 10                          -911.0  6.238773e-14                   3.2
# 11                          -911.0  1.998447e-15                   1.2
# 12                          -911.0  3.730601e-15                   0.8
# 13                          -911.0  5.223022e-13                  62.8
# 14                          -911.0  1.670351e-14                   1.2
# 15                          -911.0  1.488331e-14                   1.2
# 16                          -911.0  7.710317e-15                   1.2
# 17                          -911.0  1.368397e-14                   1.2
# 18                          -911.0  2.302238e-15                   1.2
# 19                          -911.0  1.128801e-15                   1.2
# 20                          -911.0  5.863288e-15                   1.2
# 21                          -911.0  8.729579e-15                   1.2
# 22                          -911.0  1.201986e-14                   0.8
# 23                          -911.0  1.411538e-14                   0.8
# 24                          -911.0  2.001724e-15                   0.8
# 25                          -911.0  1.363422e-14                   1.2
# 26                          -911.0  2.293508e-14                   0.8
# 27                          -911.0  7.140971e-15                   0.8
# 28                          -911.0  3.879769e-14                   0.8
# 29                          -911.0  1.641782e-13                   1.6
# 30                          -911.0 -4.730086e-16                   1.2
# 31                          -911.0  7.547652e-14                  23.6
# 32                          -911.0  6.396981e-13                  23.6
# 33                          -911.0  1.473637e-14                   2.4
# 34                          -911.0  1.560295e-14                   1.2
# 35                          -911.0  2.765775e-15                   0.8
# 36                          -911.0  1.227672e-14                   0.8
# 37                          -911.0  4.613887e-15                   1.2
# 38                          -911.0  1.425096e-15                   1.2
# 39                          -911.0  2.141872e-15                   1.2

# %%
# ===========================================================================================================================
# ========================================= STOP HERE File Writes ==================================================================================
# ===========================================================================================================================
results_p1.to_csv(root_results_write + "results_p1.csv")
results_p2.to_csv(root_results_write + "results_p2.csv")
results_p3.to_csv(root_results_write + "results_p3.csv")

# %% [markdown]
# # Results Anlaysis

# %%
results_p1.columns
# Out:
# Index(['Participant', 'DateList', 'FileName', 'Human Rater', 'RandomPeaks',
#        'Method1_TimeBased', 'Method3_FreqBased', 'width_threshold',
#        'Method3_DominantFreqLowerBound', 'Method3_DominantFreqUpperBound',
#        'SNR_mean_std', 'Method3_DominantFreq'],
#       dtype='object')

# %%
results_p1["FileName"].shape
# Out:
# (41,)

# %%
results_p1 = results_p1[results_p1.Method1_TimeBased != -911.0]

results_p1 = results_p1.drop(["Method3_DominantFreqUpperBound","Method3_DominantFreqLowerBound"],axis=1)

# %%
results_p1.columns
# Out:
# Index(['Unnamed: 0', 'Participant', 'DateList', 'FileName', 'Human Rater',
#        'RandomPeaks', 'Method1_TimeBased', 'Method3_FreqBased',
#        'width_threshold', 'SNR_mean_std', 'Method3_DominantFreq'],
#       dtype='object')

# %%
fig3= go.Figure()
fig3.add_trace(go.Bar(
    x=results_p1["FileName"],
    y=results_p1["Human Rater"],
    name='Human Rater',
    marker_color='green'
))
                  
fig3.add_trace(go.Bar(
    x=results_p1["FileName"],
    y= results_p1["Method1_TimeBased"],#results_p1[results_p1.Method1_TimeBased !=-911.0],
    name='Time Based',
    marker_color='blue'
))
fig3.add_trace(go.Bar(
    x=results_p1["FileName"],
    y= results_p1["Method3_FreqBased"], #results_p1[results_p1.Method3_FreqBased !=-911.0],
    name='Frequency Based',
    marker_color='indianred'
))

fig3.show()
# True Positive Rate (sensitivity) - TP/TP+FN
# True Negative Rate (specificity) - TN/TN+FP
# Out:
# <div>                            <div id="ed112c93-88f9-460c-aebf-c29692bd82d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed112c93-88f9-460c-aebf-c29692bd82d5")) {                    Plotly.newPlot(                        "ed112c93-88f9-460c-aebf-c29692bd82d5",                        [{"marker":{"color":"green"},"name":"Human Rater","x":["rg_20210625-172211.csv","rg_20210625-071807.csv","rg_20210624-170825.csv","rg_20210706-070145.csv","rg_20210701-212116.csv","rg_20210701-070904.csv","rg_20210630-071412.csv","rg_20210630-221335.csv","rg_20210628-081600.csv","rg_20210628-070900.csv","rg_20210629-063713.csv","rg_20210629-194025.csv","rg_20210627-122353.csv","rg_20210627-093647.csv","rg_20210704-145340.csv","rg_20210704-074924.csv","rg_20210702-065005.csv","rg_20210702-185148.csv","rg_20210705-191026.csv","rg_20210705-125950.csv","lg_20210625-172211.csv","lg_20210625-071807.csv","lg_20210624-170825.csv","lg_20210706-070145.csv","lg_20210701-212116.csv","lg_20210701-070904.csv","lg_20210630-071412.csv","lg_20210630-221335.csv","lg_20210628-081600.csv","lg_20210628-070900.csv","lg_20210629-063713.csv","lg_20210629-194025.csv","lg_20210627-122353.csv","lg_20210627-093647.csv","lg_20210704-145340.csv","lg_20210704-074924.csv","lg_20210703-070405.csv","lg_20210702-065005.csv","lg_20210702-185148.csv","lg_20210705-191026.csv","lg_20210705-125950.csv"],"y":[9,7,8,9,9,8,8,7,7,8,9,8,8,8,9,8,8,9,
" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f25047b6-c256-47e8-b768-53a0ae4f7052")) {                    Plotly.newPlot(                        "f25047b6-c256-47e8-b768-53a0ae4f7052",                        [{"marker":{"color":"#17becf"},"name":"Frequency Based","x":["rg_20210625-172211.csv","rg_20210625-071807.csv","rg_20210624-170825.csv","rg_20210706-070145.csv","rg_20210701-212116.csv","rg_20210701-070904.csv","rg_20210630-071412.csv","rg_20210630-221335.csv","rg_20210628-081600.csv","rg_20210628-070900.csv","rg_20210629-063713.csv","rg_20210629-194025.csv","rg_20210627-122353.csv","rg_20210627-093647.csv","rg_20210704-145340.csv","rg_20210704-074924.csv","rg_20210702-065005.csv","rg_20210702-185148.csv","rg_20210705-191026.csv","rg_20210705-125950.csv","lg_20210625-172211.csv","lg_20210625-071807.csv","lg_20210624-170825.csv","lg_20210706-070145.csv","lg_20210701-212116.csv","lg_20210701-070904.csv","lg_20210630-071412.csv","lg_20210630-221335.csv","lg_20210628-081600.csv","lg_20210628-070900.csv","lg_20210629-063713.csv","lg_20210629-194025.csv","lg_20210627-122353.csv","lg_20210627-093647.csv","lg_20210704-145340.csv","lg_20210704-074924.csv","lg_20210703-070405.csv","lg_20210702-065005.csv","lg_20210702-185148.csv","lg_20210705-191026.csv","lg_20210705-125950.csv"],"y":[3.919041521300584e-15,2.726990533834939e-15,1.7473699478949257e-15,1.6641504097039458e-15,5.590564941644295e-15,2.1941175803506564e-15,3.025635897758598e-15,3.747262424077954e-15,7.472725514679698e-15,-3.5789354094351683e-16,7.135631224790707e-15,9.512503042264155e-15,1.7760041024021433e-15,5.229091134848251e-15,9.318159142730396e-16,3.188666300362589e-15,6.418309051327389e-15,6.282366838661915e-15,1.8182878027239712e-15,7.067641629531637e-15,4.47311184032431e-14,2.0969637534157415e-15,7.329697421918309e-15,3.5187475418076406e-14,2.4616020424210965e-14,1.1982423965971242e-13,6.6792809583324125e-15,3.014472925160743e-15,4.86441767388009e-15,3.027082349673979e-14,3.4424969883341305e-15,5.2009763772986486e-15,5.2535441294575704e-14,1.6273083742493447e-14,1.3672645739320976e-14,6.293732033919849e-14,1.5963549540516408e-13,4.801433107932084e-15,1.4455573381132723e-14,1.3493940429594445e-13,3.588370228729975e-15],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %% [markdown]
# ### Plotting stuff

# %%
fig2 = make_subplots(rows=7, cols=1, vertical_spacing = 0.13,subplot_titles=(
        #str(column_id)+": Number of Peaks- " +str(len(indices)) + "<br>" + "Width: " + str(width) + " Distance: "+ str(heigth) + " Prominance: "+ str(prominance),"Filtered Signal"," Peak Widthds <br> " + "Mean: "+str(results_half[0].mean()),"Peak Prominances <br> Mean: " +str(peak_prominence[0].mean()),"Valley Widths Mean: " + str(valley_widths[0].mean()),"Raw FFT","Filtered FFT "
        )
        )

# %%
fig2.add_trace(go.Scatter(y = normalized_arr.ravel(),marker_color='teal'), 1, 1)

fig2.add_trace(go.Scatter(
    x=valley_idx,
    y=[normalized_arr.ravel()[j] for j in valley_idx],
    mode='markers',
    marker=dict(
        size=5,
        color='red',
        symbol='circle'
    ),
        name='Detectd valleys'
),1,1)
    # indices
fig2.add_trace(go.Scatter(
    x=indices,
    y=peaks,
    mode='markers',
    marker=dict(
        size=5,
        color='blue',
        symbol='circle'
    ),
        name='Detectd Peaks'
    ),1,1)
# Out:
# --------------------------------------------------------------
# NameError                    Traceback (most recent call last)
# <ipython-input-55-d20249abac38> in <module>
# ----> 1 fig2.add_trace(go.Scatter(y = normalized_arr.ravel(),marker_color='teal'), 1, 1)
#       2
#       3 fig2.add_trace(go.Scatter(
#       4     x=valley_idx,
#       5     y=[normalized_arr.ravel()[j] for j in valley_idx],
#
# NameError: name 'normalized_arr' is not defined

# %%
fig2.add_trace(go.Scatter(y = filtered_sig.real,marker_color='teal'), 2, 1)
fig2.add_trace(go.Scatter(
    x=filt_indices,
    y=filt_peaks,
    mode='markers',
    marker=dict(
        size=5,
        color='blue',
        symbol='circle'
    ),
        name='Detectd Peaks'
    ),2,1)

# %%
fig2.add_trace(go.Scatter(y =normalized_arr.ravel(),marker_color='teal',name=""), 3, 1)
fig2.add_trace(go.Scatter(
    x=filt_indices,
    y=[normalized_arr.ravel()[j] for j in filt_indices],
    mode='markers',
        marker=dict(
            size=5,
            color='blue',
            symbol='circle'
        ),
            name='Detectd Peaks'
        ),3,1)
fig2.add_trace(go.Bar(x=np.arange(0,len(results_half[0])), y=results_half[0],text=results_half[0],
textposition='auto',marker_color='blue', name='Detectd Peaks (Peak Width)'), 4, 1)

# %%
#fig2.add_trace(go.Bar(x=np.arange(0,len(peak_prominence[0])), y=peak_prominence[0],text=peak_prominence[0],
#        textposition='auto',marker_color='blue',name='Detectd Peaks'), 5, 1)
# fig2.add_trace(go.Bar(x=np.arange(0,len(valley_widths[0])), y=valley_widths[0],text=valley_widths[0],
#         textposition='auto',marker_color='red',name='Detectd Valleys'), 6, 1)
fig2.add_trace(go.Scatter(x = filtered_frequency,y = filtered_amplitude,marker_color='teal'), 6, 1)
fig2.add_trace(go.Scatter(x = filt_f,y = filt_P1,marker_color='teal'), 7, 1)
# fig2.update_yaxes(title_text="Voltage", title_font_family="IBM Plex San", row=1, col=1)
# fig2.update_xaxes(title_text="Number of Samples",row=1, col=1)
# fig2.update_yaxes(title_text="Peak Width", title_font_family="IBM Plex San", row=3, col=1)
# fig2.update_xaxes(title_text="Number of Peaks",row=2, col=1)
# fig2.update_yaxes(title_text="Peak Prominance", title_font_family="IBM Plex San", row=4, col=1)
# fig2.update_xaxes(title_text="Number of peaks",row=3, col=1)
    
# fig2.update_yaxes(title_text="Number of Peaks", title_font_family="IBM Plex San", row=5, col=1)
# fig2.update_xaxes(title_text="Frequency in Hz",row=4, col=1)
large_rockwell_template = dict(
layout=go.Layout(title_font=dict(family="Rockwell")))
fig2.update_layout(
    font_family="IBM Plex Sans",
    title= "" ,
    template=large_rockwell_template,height=900, width=1000)

# %%
results_p4 = read_iotex_data("Participant4")
# Out:
# 0      Participant1
# 1      Participant1
# 2      Participant1
# 3      Participant1
# 4      Participant1
#            ...
# 154    Participant4
# 155    Participant4
# 156    Participant4
# 157    Participant4
# 158    Participant4
# Name: Participant, Length: 159, dtype: object
# =========================== Participant4/2021-10-28/rg_20211028-175651.csv ===========================
# Index of row index:  118
# df_finger_tappin unique():  [1]
# df_finger_tapping.shape:  (960, 20)
# [1] (160, 20)
# len(df_finger_tapping_2_5_index_norm):  1 160
# Number of Peaks:  6
# Dominant frequency (freq where the amplitude is the heightse):  1.6
# filt_peaks:  4
# index:  118
# =========================== Participant4/2021-10-28/rg_20211028-115244.csv ===========================
# --------------------------------------------------------------
# EmptyDataError               Traceback (most recent call last)
# <ipython-input-38-37d28c269662> in <module>
# ----> 1 results_p4 = read_iotex_data("Participant4")
#
# <ipython-input-29-179f22ec91db> in read_iotex_data(participant_id)
#      21         print("===========================",row["Participant"] +"/"+ row["DateList"] + "/" + row["FileName"],"===========================")
#      22 #         if row["FileName"].startswith("rg_"):
# ---> 23         df = pd.read_csv(root+row["Participant"] +"/"+ row["DateList"] + "/" + row["FileName"])
#      24         print("Index of row index: ",index)
#      25         # Subset the Finger tapping activity.
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# ~/opt/anaconda3/envs/edear/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
dset_path = "/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/"
# file_id = []
for i in range(1):
    pno = i+1
    print("Part No: {}".format(pno))
    # csv_files = glob.glob('C:/Users/dan95/Desktop/Participant1/**/*.csv',recursive=True)
    dset_csv_fpath = dset_path +'/Participant'+str(pno)+'/**/*.csv'
    # print("dset_csv_fpath: ",dset_csv_fpath)
    label_text_fpath = dset_path +'/Participant'+str(pno)+ "/**/*.txt"
    print("label_text_fpath: ", label_text_fpath)
    csv_files = glob.glob(dset_csv_fpath,recursive=True)
    #print("csv_files: ",csv_files)
    text_files = glob.glob(label_text_fpath,recursive=True)
    rg_files = [s for s in csv_files if "rg_" in s]
    lg_files = [s for s in csv_files if "lg_" in s]
    #print("rg_files: ",rg_files)
    #print("len(rg_files),rg_files: ",len(rg_files),rg_files)
    all_sessions = []
    for file, text_file in zip(rg_files,text_files):
        print("file: ",file)
        with open(text_file) as f:
            lines = f.readlines()
       # print("medication state: ",lines[5],lines[4])
        df = pd.read_csv(file)
        df =df[df["activity"]==1]
#         df_peaks_valleys, peak_indexs, valley_idxs,peak_points = peaks_and_valleys(df)
#         print("file.split [12]: ",file.split("/")[11])
#         #df.to_csv(dset_path +'/Participant'+str(pno) + "/"+ file.split("/")[12] + "/" + file.split("/")[13] + "_peak_results.csv",index=0)
#         rise_time_arr  = rise_time(peak_indexs,valley_idxs)
#         print("peak_points,rise_time_arr: ",len(peak_points),len(rise_time_arr))
#         # print("rise_time_arr: ",rise_time_arr)
#        # print("rise_time_arr: ", rise_time_arr)
#         # create a list of medication statius same length as rise_time array.
#         med_status = [lines[4]] * len(peak_points) 
#         # gets the dates of the participants. 
#         date_list = [file.split("/")[11]] * len(peak_points)
#         file_id = [file.split("/")[12]] *len(peak_points)
#         session1 = pd.DataFrame(
#             {#'rise_time_arr_seconds': rise_time_arr,
#             'peak_amplitude': peak_points,
#              'med_status': med_status,
#             'date_list': date_list,
#             'file_id_session_num': file_id
#             })
#         all_sessions.append(session1)
#     all_sessions_df = pd.concat(all_sessions)
# all_sessions_df.to_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/peak_amplitudes.csv",index=0)
# Out:
# Part No: 1
# label_text_fpath:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/**/*.txt
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-25/rg_20210625-172211.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-25/rg_20210625-071807.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-24/rg_20210624-170825.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-06/rg_20210706-070145.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-01/rg_20210701-212116.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-01/rg_20210701-070904.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-30/rg_20210630-071412.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-30/rg_20210630-221335.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-28/rg_20210628-081600.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-28/rg_20210628-070900.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-29/rg_20210629-063713.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-29/rg_20210629-063713.csv_peak_results.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-29/rg_20210629-194025.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-29/rg_20210629-194025.csv_peak_results.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-27/rg_20210627-122353.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-27/rg_20210627-093647.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-04/rg_20210704-145340.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-04/rg_20210704-074924.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-03/rg_20210703-070405.csv
# file:  /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-07-02/rg_20210702-065005.csv

# %% [markdown]
# ### Create a list of file paths

# %%
# list all files ending with a .txt.
all_files_txt = glob.glob("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/*")

#print("all_files_txt = ",all_files_txt,len(all_files_txt))
participant_list = []
date_list = []
num_task = []
file_paths_lg = []
counter_lg = 0
file_paths_rg = []
file_paths_txt = []
participant_list_lg = []
date_list_lg_all = []
file_name_lg_all = []
participant_list_rg = []
date_list_rg_all = []
file_name_rg_all = []
participant_list_txt = []
date_list_txt_all = []
file_name_txt_all = []
# Read Files.
for full_path in all_files_txt:
    #print("ROOT FOLDER PATH ",full_path)
    all_folder_dates =  glob.glob(full_path + "/*")
    #print(all_folder_dates) 
    # Get a list of dates based on Participant ID
    for dates_folder in all_folder_dates:
        d_split = dates_folder.split("/")
        #print("d_split == \n",d_split[9],d_split[10])
        participant_list.append(d_split[9])
        date_list.append(d_split[10])
        #list all .csvfiles in that dates folder.
        dates_folder_files = glob.glob(dates_folder + "/*")
        for i in dates_folder_files:
            #print(i.split("/"))
            file_name = i.split("/")[12]
            if file_name.startswith("lg"):
                print("LG",i.split("/")[9],i.split("/")[10] , file_name)
                counter_lg+=1
                print("counter_lg = \n",counter_lg)
                print(i)
                participant_list_lg.append(i.split("/")[10])
                date_list_lg_all.append(i.split("/")[11])
                file_name_lg_all.append(i.split("/")[12])
                #num_task.append(counter_lg)
                file_paths_lg.append(i)
            if file_name.startswith("rg"):
                participant_list_rg.append(i.split("/")[10])
                date_list_rg_all.append(i.split("/")[11])
                file_paths_rg.append(i.split("/")[12])
            if file_name.endswith(".txt"):
                participant_list_txt.append(i.split("/")[10])
                date_list_txt_all.append(i.split("/")[11])
                file_paths_txt.append(i.split("/")[12])
        num_task.append(counter_lg)
        counter_lg = 0 # Reset counting fils after each date is visited.
# Out:
# LG PD Participant1 lg_20210625-172211.csv
# counter_lg =
#  1
# /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06-25/lg_20210625-172211.csv
# LG PD Participant1 lg_20210625-071807.csv
# counter_lg =
#  2
# /Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant1/2021-06
users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/PD/Participant2/2021-07-05/lg_20210705-100219.csv

# %%
print(len(participant_list_lg),len(date_list_lg_all),len(file_name_lg_all))
print(len(participant_list_rg),len(date_list_rg_all),len(file_paths_rg))
print(len(participant_list_txt),len(date_list_txt_all),len(file_paths_txt))
# Out:
# 79 79 79
# 80 80 80
# 77 77 77

# %%
df_file_paths_lg = pd.DataFrame(
    {'ParticipantList': participant_list_lg,
     'DateList': date_list_lg_all,
     "FileName":file_name_lg_all 
    })
df_file_paths_rg = pd.DataFrame(
    {'ParticipantList': participant_list_rg,
     'DateList': date_list_rg_all,
     "FileName":file_paths_rg 
    })
df_file_paths_txt = pd.DataFrame(
    {'ParticipantList': participant_list_txt,
     'DateList': date_list_txt_all,
     "FileName":file_paths_txt 
    })

# %%
str_filetime = df_file_paths_rg.iloc[0]["FileName_RightGlove"].split("-")[1].split(".")[0]
str_filetime[:2] # Take only the first hour.
# Out:
# '17'

# %%
str_filetime_info = df_file_paths_txt.iloc[1]["FileName_InfoGlove"].split("-")[1].split("_")[0]
str_filetime_info[:2]
# Out:
# '17'

# %%
if int(str_filetime[:2]) == int(str_filetime_info[:2]):
    print((df_file_paths_rg.iloc[0]["FileName_RightGlove"] ,df_file_paths_txt.iloc[0]["FileName_InfoGlove"]))
# Out:
# ('rg_20210625-172211.csv', '20210625-072017_patient_form.txt')

# %%
df_file_paths_txt["DateList"].unique()[0]
# Out:
# '2021-06-25'

# %%
# make a subset of the df by date first.
df_file_paths_txt_subset_day = df_file_paths_txt[df_file_paths_txt["DateList"]==df_file_paths_txt["DateList"].unique()[0]]

df_file_paths_txt_subset_day
# Out:
#   ParticipantList    DateList                FileName_InfoGlove
# 0    Participant1  2021-06-25  20210625-072017_patient_form.txt
# 1    Participant1  2021-06-25  20210625-172343_patient_form.txt

# %%
df_file_paths_rg_subset_day
# Out:
#    ParticipantList    DateList     FileName_RightGlove
# 63    Participant4  2021-10-24  rg_20211024-190618.csv
# 64    Participant4  2021-10-24  rg_20211024-093205.csv

# %%
len(df_file_paths_rg["DateList"].unique())
len(df_file_paths_txt["DateList"].unique())
# Out:
# 33

# %%
# Out:
#    ParticipantList    DateList     FileName_RightGlove
# 0     Participant1  2021-06-25  rg_20210625-172211.csv
# 1     Participant1  2021-06-25  rg_20210625-071807.csv
# 2     Participant1  2021-06-24  rg_20210624-170825.csv
# 3     Participant1  2021-07-06  rg_20210706-070145.csv
# 4     Participant1  2021-07-01  rg_20210701-212116.csv
# ..             ...         ...                     ...
# 75    Participant2  2021-07-03  rg_20210703-083853.csv
# 76    Participant2  2021-07-02  rg_20210702-144253.csv
# 77    Participant2  2021-07-02  rg_20210702-171944.csv
# 78    Participant2  2021-07-05  rg_20210705-100219.csv
# 79    Participant2  2021-07-05  rg_20210705-105203.csv
#
# [80 rows x 3 columns]

# %%
def file_list(df_file_paths_rg,df_file_paths_txt):
    rg_fp = []
    meds_fp = []
    new_date_list = []
    participant_id = "Participant4"
    part_uniq_day = df_file_paths_txt[df_file_paths_txt["ParticipantList"]==participant_id]["DateList"].unique()
    for idx, day in enumerate(part_uniq_day):
        df_file_paths_rg_subset_day = df_file_paths_rg[df_file_paths_rg["ParticipantList"]==participant_id]
        df_file_paths_txt_subset_day = df_file_paths_txt[df_file_paths_txt["ParticipantList"]==participant_id]
        print("Unique Day :================",df_file_paths_rg["DateList"].unique()[idx],"================")
        df_file_paths_rg_subset_day =  df_file_paths_rg_subset_day[ df_file_paths_rg_subset_day["DateList"]== df_file_paths_rg_subset_day["DateList"].unique()[idx]]
        df_file_paths_txt_subset_day = df_file_paths_txt_subset_day[df_file_paths_txt_subset_day["DateList"]==df_file_paths_txt_subset_day["DateList"].unique()[idx]]
        print(df_file_paths_txt_subset_day)
        for index, row in df_file_paths_txt_subset_day.iterrows():
            str_filetime_info = df_file_paths_txt.iloc[index]["FileName"].split("-")[1].split("_")[0]
            for index2, row2 in df_file_paths_rg_subset_day.iterrows():
                str_filetime_rg = df_file_paths_rg.iloc[index2]["FileName"].split("-")[1].split(".")[0]
                #print("int(str_filetime_info=",int(str_filetime_info[:2]))
                #print("int(str_filetime_rg=",int(str_filetime_rg[:2]))
                if int(str_filetime_rg[:2]) == int(str_filetime_info[:2]):
                    print("Matching pairs for Meds",(str_filetime_rg ,str_filetime_info))
                    print("Matching File Paths for Meds",(df_file_paths_rg.iloc[index2]["FileName"],df_file_paths_txt.iloc[index]["FileName"].split("-")[1]))
                    rg_fp.append(df_file_paths_rg.iloc[index2]["FileName"])
                    meds_fp.append(df_file_paths_txt.iloc[index]["FileName"].split("-")[1])
                    new_date_list.append(df_file_paths_rg.iloc[index2]["DateList"])
    return rg_fp, meds_fp, new_date_list

# %%
rg_fp, meds_fp, new_date_list = file_list(df_file_paths_rg,df_file_paths_txt)
# Out:
# Unique Day :================ 2021-06-25 ================
#    ParticipantList    DateList                          FileName
# 40    Participant4  2021-10-28  20211028-175903_patient_form.txt
# 41    Participant4  2021-10-28  20211028-115426_patient_form.txt
# Matching pairs for Meds ('175651', '175903')
# Matching File Paths for Meds ('rg_20211028-175651.csv', '175903_patient_form.txt')
# Matching pairs for Meds ('115244', '115426')
# Matching File Paths for Meds ('rg_20211028-115244.csv', '115426_patient_form.txt')
# Unique Day :================ 2021-06-24 ================
#    ParticipantList    DateList                          FileName
# 42    Participant4  2021-10-21  20211021-165915_patient_form.txt
# Matching pairs for Meds ('165751', '165915')
# Matching File Paths for Meds ('rg_20211021-165751.csv', '165915_patient_form.txt')
# Unique Day :================ 2021-07-06 ================
#    ParticipantList    DateList                          FileName
# 43    Participant4  2021-10-19  20211019-214722_patient_form.txt
# 44    Participant4  2021-10-19  20211019-173056_patient_form.txt
# Matching pairs for Meds ('214518', '214722')
# Matching File Paths for Meds ('rg_20211019-214518.csv', '214722_patient_form.txt')
# Matching pairs for Meds ('172844', '173056')
# Matching File Paths for Meds ('rg_20211019-172844.csv', '173056_patient_form.txt')
# Unique Day :================ 2021-07-01 ================
#    ParticipantList    DateList                          FileName
# 45    Participant4  2021-10-27  20211027-184918_patient_form.txt
# 46    Participant4  2021-10-27  20211027-065429_patient_form.txt
# Matching pairs for Meds ('184737', '184918')
# Matching File Paths for Meds ('rg_20211027-184737.csv', '184918_patient_form.txt')
# Matching pairs for Meds ('065226', '065429')
# Matching File Paths for Meds ('rg_20211027-065226.csv', '065429_patient_form.txt')
# Unique Day :================ 2021-06-30 ================
#    ParticipantList    DateList                          FileName
# 47    Participant4  2021-10-18  20211018-185058_patient_form.txt
# Matching pairs for Meds ('184648', '185058')
# Matching File Paths for Meds ('rg_20211018-184648.csv', '185058_patient_form.txt')
# Unique Day :================ 2021-06-28 ================
#    ParticipantList    DateList                          FileName
# 48    Participant4  2021-10-20  20211020-191005_patient_form.txt
# 49    Participant4  2021-10-20  20211020-105539_patient_form.txt
# Matching pairs for Meds ('190820', '191005')
# Matching File Paths for Meds ('rg_20211020-190820.csv', '191005_patient_form.txt')
# Matching pairs for Meds ('105349', '105539')
# Matching File Paths for Meds ('rg_20211020-105349.csv', '105539_patient_form.txt')
# Unique Day :================ 2021-06-29 ================
#    ParticipantList    DateList                          FileName
# 50    Participant4  2021-10-29  20211029-183210_patient_form.txt
# 51    Participant4  2021-10-29  20211029-153339_patient_form.txt
# Matching pairs for Meds ('182954', '183210')
# Matching File Paths for Meds ('rg_20211029-182954.csv', '183210_patient_form.txt')
# Matching pairs for Meds ('153037', '153339')
# Matching File Paths for Meds ('rg_20211029-153037.csv', '153339_patient_form.txt')
# Unique Day :================ 2021-06-27 ================
#    ParticipantList    DateList                          FileName
# 52    Participant4  2021-10-30  20211030-190124_patient_form.txt
# 53    Participant4  2021-10-30  20211030-095535_patient_form.txt
# Matching pairs for Meds ('095315', '095535')
# Matching File Paths for Meds ('rg_20211030-095315.csv', '095535_patient_form.txt')
# Unique Day :================ 2021-07-04 ================
#    ParticipantList    DateList                          FileName
# 54    Participant4  2021-10-31  20211031-190741_patient_form.txt
# 55    Participant4  2021-10-31  20211031-133216_patient_form.txt
# Matching pairs for Meds ('190553', '190741')
# Matching File Paths for Meds ('rg_20211031-190553.csv', '190741_patient_form.txt')
# Matching pairs for Meds ('133028', '133216')
# Matching File Paths for Meds ('rg_20211031-133028.csv', '133216_patient_form.txt')
# Unique Day :================ 2021-07-03 ================
#    ParticipantList    DateList                          FileName
# 56    Participant4  2021-10-22  20211022-133733_patient_form.txt
# 57    Participant4  2021-10-22  20211022-053304_patient_form.txt
# Matching pairs for Meds ('133556', '133733')
# Matching File Paths for Meds ('rg_20211022-133556.csv', '133733_patient_form.txt')
# Matching pairs for Meds ('053129', '053304')
# Matching File Paths for Meds ('rg_20211022-053129.csv', '053304_patient_form.txt')
# Unique Day :================ 2021-07-02 ================
#    ParticipantList    DateList                          FileName
# 58    Participant4  2021-10-23  20211023-113522_patient_form.txt
# 59    Participant4  2021-10-23  20211023-190347_patient_form.txt
# Matching pairs for Meds ('113331', '113522')
# Matching File Paths for Meds ('rg_20211023-113331.csv', '113522_patient_form.txt')
# Matching pairs for Meds ('190114', '190347')
# Matching File Paths for Meds ('rg_20211023-190114.csv', '190347_patient_form.txt')
# Unique Day :================ 2021-07-05 ================
#    ParticipantList    DateList                          FileName
# 60    Participant4  2021-10-24  20211024-093913_patient_form.txt
# Matching pairs for Meds ('093205', '093913')
# Matching File Paths for Meds ('rg_20211024-093205.csv', '093913_patient_form.txt')

# %%
lg_fp, meds_fp2, new_lg_date_list = file_list(df_file_paths_lg,df_file_paths_txt)
# Out:
# Unique Day :================ 2021-06-25 ================
#    ParticipantList    DateList                          FileName
# 40    Participant4  2021-10-28  20211028-175903_patient_form.txt
# 41    Participant4  2021-10-28  20211028-115426_patient_form.txt
# Matching pairs for Meds ('175651', '175903')
# Matching File Paths for Meds ('lg_20211028-175651.csv', '175903_patient_form.txt')
# Matching pairs for Meds ('115244', '115426')
# Matching File Paths for Meds ('lg_20211028-115244.csv', '115426_patient_form.txt')
# Unique Day :================ 2021-06-24 ================
#    ParticipantList    DateList                          FileName
# 42    Participant4  2021-10-21  20211021-165915_patient_form.txt
# Matching pairs for Meds ('165751', '165915')
# Matching File Paths for Meds ('lg_20211021-165751.xlsx', '165915_patient_form.txt')
# Matching pairs for Meds ('165751', '165915')
# Matching File Paths for Meds ('lg_20211021-165751.csv', '165915_patient_form.txt')
# Unique Day :================ 2021-07-06 ================
#    ParticipantList    DateList                          FileName
# 43    Participant4  2021-10-19  20211019-214722_patient_form.txt
# 44    Participant4  2021-10-19  20211019-173056_patient_form.txt
# Matching pairs for Meds ('214518', '214722')
# Matching File Paths for Meds ('lg_20211019-214518.csv', '214722_patient_form.txt')
# Matching pairs for Meds ('172844', '173056')
# Matching File Paths for Meds ('lg_20211019-172844.csv', '173056_patient_form.txt')
# Unique Day :================ 2021-07-01 ================
#    ParticipantList    DateList                          FileName
# 45    Participant4  2021-10-27  20211027-184918_patient_form.txt
# 46    Participant4  2021-10-27  20211027-065429_patient_form.txt
# Matching pairs for Meds ('184737', '184918')
# Matching File Paths for Meds ('lg_20211027-184737.csv', '184918_patient_form.txt')
# Matching pairs for Meds ('065226', '065429')
# Matching File Paths for Meds ('lg_20211027-065226.csv', '065429_patient_form.txt')
# Unique Day :================ 2021-06-30 ================
#    ParticipantList    DateList                          FileName
# 47    Participant4  2021-10-18  20211018-185058_patient_form.txt
# Matching pairs for Meds ('184648', '185058')
# Matching File Paths for Meds ('lg_20211018-184648.csv', '185058_patient_form.txt')
# Unique Day :================ 2021-06-28 ================
#    ParticipantList    DateList                          FileName
# 48    Participant4  2021-10-20  20211020-191005_patient_form.txt
# 49    Participant4  2021-10-20  20211020-105539_patient_form.txt
# Matching pairs for Meds ('190820', '191005')
# Matching File Paths for Meds ('lg_20211020-190820.csv', '191005_patient_form.txt')
# Matching pairs for Meds ('105349', '105539')
# Matching File Paths for Meds ('lg_20211020-105349.csv', '105539_patient_form.txt')
# Unique Day :================ 2021-06-29 ================
#    ParticipantList    DateList                          FileName
# 50    Participant4  2021-10-29  20211029-183210_patient_form.txt
# 51    Participant4  2021-10-29  20211029-153339_patient_form.txt
# Matching pairs for Meds ('182954', '183210')
# Matching File Paths for Meds ('lg_20211029-182954.csv', '183210_patient_form.txt')
# Matching pairs for Meds ('153037', '153339')
# Matching File Paths for Meds ('lg_20211029-153037.csv', '153339_patient_form.txt')
# Unique Day :================ 2021-06-27 ================
#    ParticipantList    DateList                          FileName
# 52    Participant4  2021-10-30  20211030-190124_patient_form.txt
# 53    Participant4  2021-10-30  20211030-095535_patient_form.txt
# Matching pairs for Meds ('095315', '095535')
# Matching File Paths for Meds ('lg_20211030-095315.csv', '095535_patient_form.txt')
# Unique Day :================ 2021-07-04 ================
#    ParticipantList    DateList                          FileName
# 54    Participant4  2021-10-31  20211031-190741_patient_form.txt
# 55    Participant4  2021-10-31  20211031-133216_patient_form.txt
# Matching pairs for Meds ('190553', '190741')
# Matching File Paths for Meds ('lg_20211031-190553.csv', '190741_patient_form.txt')
# Matching pairs for Meds ('133028', '133216')
# Matching File Paths for Meds ('lg_20211031-133028.csv', '133216_patient_form.txt')
# Unique Day :================ 2021-07-03 ================
#    ParticipantList    DateList                          FileName
# 56    Participant4  2021-10-22  20211022-133733_patient_form.txt
# 57    Participant4  2021-10-22  20211022-053304_patient_form.txt
# Matching pairs for Meds ('133556', '133733')
# Matching File Paths for Meds ('lg_20211022-133556.csv', '133733_patient_form.txt')
# Matching pairs for Meds ('053129', '053304')
# Matching File Paths for Meds ('lg_20211022-053129.csv', '053304_patient_form.txt')
# Unique Day :================ 2021-07-02 ================
#    ParticipantList    DateList                          FileName
# 58    Participant4  2021-10-23  20211023-113522_patient_form.txt
# 59    Participant4  2021-10-23  20211023-190347_patient_form.txt
# Matching pairs for Meds ('113331', '113522')
# Matching File Paths for Meds ('lg_20211023-113331.csv', '113522_patient_form.txt')
# Matching pairs for Meds ('190114', '190347')
# Matching File Paths for Meds ('lg_20211023-190114.csv', '190347_patient_form.txt')
# Unique Day :================ 2021-07-05 ================
#    ParticipantList    DateList                          FileName
# 60    Participant4  2021-10-24  20211024-093913_patient_form.txt
# Matching pairs for Meds ('093205', '093913')
# Matching File Paths for Meds ('lg_20211024-093205.csv', '093913_patient_form.txt')

# %%
df_file_paths_rg_info_sync = pd.DataFrame({
     'DateList': new_date_list,
     "FileName":rg_fp ,
    "FileName_InfoGlove":meds_fp })

df_file_paths_lg_info_sync = pd.DataFrame({
     'DateList': new_lg_date_list,
     "FileName":lg_fp ,
    "FileName_InfoGlove":meds_fp2 })

result = pd.concat([df_file_paths_rg_info_sync,df_file_paths_lg_info_sync])

# %%
result.to_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/Project_IOTEX/iotex-glove/info_sync_filepaths_p4.csv",index=0)

# %%
#df_file_paths.to_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/iotex-glove/lg_file_path.csv",index=0)
print(len(participant_list),len(date_list),len(num_task),len(file_paths_lg),len(file_paths_rg))
df_dates_pid = pd.DataFrame(
    {'ParticipantList': participant_list,
     'DateList': date_list,
     "NumTasks":num_task 
    })
# df_dates_pid.to_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/Graduate/WBL/iotex-glove/pd_dates_list.csv",index=0)
